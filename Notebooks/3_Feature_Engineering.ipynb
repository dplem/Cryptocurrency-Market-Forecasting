# %% [markdown]
# # Feature Engineering

# %%
import pandas as pd

# disable chained assignments
pd.options.mode.chained_assignment = None

# %% [markdown]
# ## Clean Dataset

# %%
# import dataset
cleaning = pd.read_csv('../Data/Bitcoin_sentiment.csv')
cleaning.head()
# Out:
#    Unnamed: 0        time  avg_positive  avg_neutral  avg_negative  \
# 0           0  2018-12-31      0.138213     0.791725      0.070078
# 1           1  2019-01-01      0.133899     0.801962      0.064177
# 2           2  2019-01-02      0.124542     0.805365      0.070119
# 3           3  2019-01-03      0.145012     0.785654      0.069367
# 4           4  2019-01-04      0.124144     0.801732      0.074139
#
#    avg_compound
# 0      0.133069
# 1      0.131864
# 2      0.111221
# 3      0.141588
# 4      0.123028

# %%
# Drop unnecessary columns and set time column to datetime
cleaning.drop(cleaning.columns[[0]], axis=1, inplace=True)
cleaning['time'] = pd.to_datetime(cleaning['time'])
cleaning.dtypes
# Out:
# time            datetime64[ns]
# avg_positive           float64
# avg_neutral            float64
# avg_negative           float64
# avg_compound           float64
# dtype: object

# %%
# Set index as time column
cleaning.set_index('time', inplace=True)
cleaning.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 957 entries, 2018-12-31 to 2021-09-08
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   avg_positive  957 non-null    float64
#  1   avg_neutral   957 non-null    float64
#  2   avg_negative  957 non-null    float64
#  3   avg_compound  957 non-null    float64
# dtypes: float64(4)
# memory usage: 37.4 KB

# %%
# replace all missing datetime values in index and fill with missing date and mean of values per column
cleaning.resample('D').mean()
cleaning.reset_index(inplace=True)
cleaning.head()
# Out:
#         time  avg_positive  avg_neutral  avg_negative  avg_compound
# 0 2018-12-31      0.138213     0.791725      0.070078      0.133069
# 1 2019-01-01      0.133899     0.801962      0.064177      0.131864
# 2 2019-01-02      0.124542     0.805365      0.070119      0.111221
# 3 2019-01-03      0.145012     0.785654      0.069367      0.141588
# 4 2019-01-04      0.124144     0.801732      0.074139      0.123028

# %% [markdown]
# ## Bitcoin Ticker Symbol Price

# %%
## Plot ticker symbol price
btc_df = pd.read_csv('../Data/Historical/BTC.csv')
btc_df.head()
btc_df.dtypes
# Out:
# time       object
# low       float64
# high      float64
# open      float64
# close     float64
# volume    float64
# dtype: object

# %%
# Make time column a series with dtype datetime64[ns]
btc_df['time'] = pd.to_datetime(btc_df['time'])

# %%
#greater than the start date and smaller than the end date
mask = (btc_df['time'] >= '2018-12-31T00:00') & (btc_df['time'] <= '2021-9-8T00:00')
mask_df = btc_df.loc[mask]
mask_df.head()
# Out:
#            time      low     high     open    close        volume
# 1260 2018-12-31  3625.00  3835.40  3829.00  3691.86  12799.942626
# 1261 2019-01-01  3651.02  3841.17  3691.87  3826.10  10812.884988
# 1262 2019-01-02  3770.07  3916.57  3826.10  3890.79   9982.470846
# 1263 2019-01-03  3758.07  3893.80  3890.80  3787.57   9327.647089
# 1264 2019-01-04  3730.00  3849.00  3787.57  3820.82   9225.150500

# %% [markdown]
# ## Merge Dataframes

# %%
# Convert time column to datetime
cleaning['time'] = pd.to_datetime(cleaning['time'])
df_merged = pd.merge(cleaning, mask_df, how='outer', on='time')
df_merged.head()
# Out:
#         time  avg_positive  avg_neutral  avg_negative  avg_compound      low  \
# 0 2018-12-31      0.138213     0.791725      0.070078      0.133069  3625.00
# 1 2019-01-01      0.133899     0.801962      0.064177      0.131864  3651.02
# 2 2019-01-02      0.124542     0.805365      0.070119      0.111221  3770.07
# 3 2019-01-03      0.145012     0.785654      0.069367      0.141588  3758.07
# 4 2019-01-04      0.124144     0.801732      0.074139      0.123028  3730.00
#
#       high     open    close        volume
# 0  3835.40  3829.00  3691.86  12799.942626
# 1  3841.17  3691.87  3826.10  10812.884988
# 2  3916.57  3826.10  3890.79   9982.470846
# 3  3893.80  3890.80  3787.57   9327.647089
# 4  3849.00  3787.57  3820.82   9225.150500

# %%
df_merged.dtypes
# Out:
# time            datetime64[ns]
# avg_positive           float64
# avg_neutral            float64
# avg_negative           float64
# avg_compound           float64
# low                    float64
# high                   float64
# open                   float64
# close                  float64
# volume                 float64
# dtype: object

# %%
df_merged.to_csv('../Data/merged_sentiment.csv')

# %%
test = df_merged
test.head()
# Out:
#         time  avg_positive  avg_neutral  avg_negative  avg_compound      low  \
# 0 2018-12-31      0.138213     0.791725      0.070078      0.133069  3625.00
# 1 2019-01-01      0.133899     0.801962      0.064177      0.131864  3651.02
# 2 2019-01-02      0.124542     0.805365      0.070119      0.111221  3770.07
# 3 2019-01-03      0.145012     0.785654      0.069367      0.141588  3758.07
# 4 2019-01-04      0.124144     0.801732      0.074139      0.123028  3730.00
#
#       high     open    close        volume
# 0  3835.40  3829.00  3691.86  12799.942626
# 1  3841.17  3691.87  3826.10  10812.884988
# 2  3916.57  3826.10  3890.79   9982.470846
# 3  3893.80  3890.80  3787.57   9327.647089
# 4  3849.00  3787.57  3820.82   9225.150500

# %%
# Create blank column in test dataframe
test['price_difference'] = ''

# %%
# Insert 1 or 0 depending on if the closing price went up or down
num = 1
T = int(1)
R = int(0)


try:

    for index in test.iterrows():

        # Calculate difference between two columns
        n = test['close'].iloc[T] - test['close'].iloc[R]

        # if statement to assign 1 or 0 to new column depending on value of n
        if n >= 0:
            test['price_difference'].iloc[num] = 1
        else:
            test['price_difference'].iloc[num] = 0

        # Increase values by one for each iteration
        num = int(num) + 1
        T = int(T) + 1
        R = int(R) + 1
        
except:
    pass
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-ed2c63ff0f08> in <module>
#       6
#       7     # Calculate difference between two columns
# ----> 8     n = test['close'].iloc[T] - test['close'].iloc[R]
#       9
#      10     # if statement to assign 1 or 0 to new column depending on value of n
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1499
#    1500             # validate the location
# -> 1501             self._validate_integer(key, axis)
#    1502
#    1503             return self.obj._ixs(key, axis=axis)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    1442         len_axis = len(self.obj._get_axis(axis))
#    1443         if key >= len_axis or key < -len_axis:
# -> 1444             raise IndexError("single positional indexer is out-of-bounds")
#    1445
#    1446     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %%
test.head()
# Out:
#         time  avg_positive  avg_neutral  avg_negative  avg_compound      low  \
# 0 2018-12-31      0.138213     0.791725      0.070078      0.133069  3625.00
# 1 2019-01-01      0.133899     0.801962      0.064177      0.131864  3651.02
# 2 2019-01-02      0.124542     0.805365      0.070119      0.111221  3770.07
# 3 2019-01-03      0.145012     0.785654      0.069367      0.141588  3758.07
# 4 2019-01-04      0.124144     0.801732      0.074139      0.123028  3730.00
#
#       high     open    close        volume price_difference
# 0  3835.40  3829.00  3691.86  12799.942626
# 1  3841.17  3691.87  3826.10  10812.884988                1
# 2  3916.57  3826.10  3890.79   9982.470846                1
# 3  3893.80  3890.80  3787.57   9327.647089                0
# 4  3849.00  3787.57  3820.82   9225.150500                1

# %%
#test.to_csv('../Data/cleaned_sentiment_scores_same_day.csv')
